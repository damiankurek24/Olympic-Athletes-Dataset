# %%
import pandas as pd

# %%
bios = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/Olympics-Dataset/master/athletes/bios.csv')
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 bios = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/Olympics-Dataset/master/athletes/bios.csv')
#
# ...

# %%
bios.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# ...

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Roles          145500 non-null  object
#  1   Sex            145500 non-null  object
#  2   Full name      145500 non-null  object
#  3   Used name      145500 non-null  object
#  4   Born           143772 non-null  object
#  5   Died           34042 non-null   object
#  6   NOC            145499 non-null  object
#  7   athlete_id     145500 non-null  int64
#  8   Measurements   107833 non-null  object
#  9   Affiliations   95832 non-null   object
#  10  Nick/petnames  9145 non-null    object
#  11  Title(s)       399 non-null     object
#  12  Other names    7167 non-null    object
#  13  Nationality    8259 non-null    object
#  14  Original name  30739 non-null   object
#  15  Name order     7844 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 17.8+ MB

# %%
bios = bios.dropna()

# %%
df['name'] = df['Used name'].str.replace(".", " ")

# %%
df[['height', 'weight']] =  df['Measurements'].str.split('/', expand=True)

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# ...

# %%
df['weight'] = df['weight'].str.replace('kg', '', regex=False)
df['weight'] = pd.to_numeric(df['weight'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " 64-66 "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 2
#       1 df['weight'] = df['weight'].str.replace('kg', '', regex=False)
# ----> 2 df['weight'] = pd.to_numeric(df['weight'])
#
# File c:\Users\Damiok\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
# ...

# %%
#Identyfikacja zakresów liczb

zakresy_liczbowe = df[df['weight'].str.contains('[^\d.]')]
print(zakresy_liczbowe)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Damiok\AppData\Local\Temp\ipykernel_10080\3101621085.py:3: SyntaxWarning: invalid escape sequence '\d'
#   zakresy_liczbowe = df[df['weight'].str.contains('[^\d.]')]
# C:\Users\Damiok\AppData\Local\Temp\ipykernel_10080\3101621085.py:3: SyntaxWarning: invalid escape sequence '\d'
#   zakresy_liczbowe = df[df['weight'].str.contains('[^\d.]')]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 3
#       1 #Identyfikacja zakresów liczb
# ----> 3 zakresy_liczbowe = df[df['weight'].str.contains('[^\d.]')]
#       4 print(zakresy_liczbowe)
#
# File c:\Users\Damiok\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4092, in DataFrame.__getitem__(self, key)
#    4089     return self.where(key)
# ...

# %%
df['height'] = df['height'].str.replace('cm', '', regex=False)
df['height'] = pd.to_numeric(df['height'])

# %%
df[['weight','height']]
# Out:
#        weight height
# 0         NaN    NaN
# 1         76   183
# 2         76   183
# 3         64   168
# 4         NaN    NaN
# ...       ...    ...
# 145495    61   167
# 145496    65   168
# 145497    55   163
# 145498   None   166
# 145499    NaN    NaN
#
# [145500 rows x 2 columns]
